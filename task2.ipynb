# %%
import numpy as np 
import pandas as pd
import matplotlib as mat
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Viteesh\Downloads\task files\age_salary_left_skewed.csv")
df.head()
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
le = LabelEncoder()
df.isnull().sum()
df.head()
sns.kdeplot(x="Salary",data=df)
plt.title("Salary Distribution")
# Out:
# Text(0.5, 1.0, 'Salary Distribution')

# %%
from sklearn.preprocessing import RobustScaler

# Create RobustScaler instance
robust_scaler = RobustScaler()

# Apply to numeric columns
numeric_cols = df.select_dtypes(include=[np.number]).columns
df_robust_scaled = df.copy()
df_robust_scaled[numeric_cols] = robust_scaler.fit_transform(df[numeric_cols])

df_robust_scaled.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 robust_scaler = RobustScaler()
#       6 # Apply to numeric columns
# ----> 7 numeric_cols = df.select_dtypes(include=[np.number]).columns
#       8 df_robust_scaled = df.copy()
#       9 df_robust_scaled[numeric_cols] = robust_scaler.fit_transform(df[numeric_cols])
#
# NameError: name 'df' is not defined
